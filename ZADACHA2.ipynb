# %%
# Very SLOWLY With Numpy
import pandas as pd
import numpy as np
import csv
from datetime import datetime
startTime = datetime.now()
# Konvert spisok
#spisok111 = pd.read_csv("10m.txt", sep="\t", header=None)
spisok111=np.genfromtxt("10m.txt", delimiter='\t', dtype=np.float) 
print('Working time genfromtxt is: ', datetime.now() - startTime)

# First FOUR tasks
max_value = np.max(spisok111)
min_value = np.min(spisok111)
median_value = np.median(spisok111)
average_value = np.average(spisok111)
#len_array=len(np_array)
print('The maximum value of the array is: ', max_value)
print('The minimum value of the array is: ', min_value)
print('The median value of the array is: ', median_value)
print('The average value of the array is: ', average_value)
print('Working time first FOR tasks  is: ', datetime.now() - startTime)
#print('LENGHT: ', len_array)
# End first FOUR tasks
  # Prog 1
# OPEN CSV  
f = open('1111.csv', 'w') 
writer = csv.writer(f)
reader = csv.reader(f)
# Cycle UP
z_count=1
a=0
b=a+1
for element in spisok111:
    
    if b<(len(spisok111)-1) and  spisok111[a]<spisok111[b]:
        z_count+=1
        a+=1
        b+=1
       
    else:
        
       # f.write(str(z_count) + "\n")
        writer.writerows(str(z_count))
        a+=1
        b+=1
        z_count=1
   
for element in spisok111:
    if b<(len(spisok111)-1) and  spisok111[a]<spisok111[b]:
        z_count+=1
        a+=1
        b+=1
        
    else:
       
        #f.write(str(z_count) + "\n")
        writer.writerows(str(z_count))
 
f.close()

print('Working time cycle  is: ', datetime.now() - startTime)
data = pd.read_csv("1111.csv", sep="\t", header=None)

print('Working time pandas is: ', datetime.now() - startTime)
max_value = np.max(data)
print('The maximum UP value of the array is: ', max_value)
print('Working time UP is: ', datetime.now() - startTime)

# Prog 2
# Open CSV
f2 = open('1111_1.csv', 'w') 
writer2 = csv.writer(f2)
reader2 = csv.reader(f2)
# Cycle DOWN

z_count=1
a=0
b=a+1
for element in spisok111:
    
    if b<(len(spisok111)-1) and  spisok111[a]>spisok111[b]:
        z_count+=1
        a+=1
        b+=1
       
    else:
        
       # f.write(str(z_count) + "\n")
        writer2.writerows(str(z_count))
        a+=1
        b+=1
        z_count=1
   
for element in spisok111:
    if b<(len(spisok111)-1) and  spisok111[a]>spisok111[b]:
        z_count+=1
        a+=1
        b+=1
        
    else:
               
        writer2.writerows(str(z_count))
f2.close()

print('Working time cycle  is: ', datetime.now() - startTime)
data = pd.read_csv("1111.csv", sep="\t", header=None)

print('Working time pandas is: ', datetime.now() - startTime)
max_value = np.max(data)
print('The maximum DOWN value of the array is: ', max_value)
print('Working time DOWN is: ', datetime.now() - startTime)
# Out:
# Working time genfromtxt is:  0:00:53.437786
# The maximum value of the array is:  49999978.0
# The minimum value of the array is:  -49999996.0
# The median value of the array is:  25216.0
# The average value of the array is:  7364.418442641844
# Working time first FOR tasks  is:  0:00:53.734823
# Working time cycle  is:  0:02:11.807737
# Working time pandas is:  0:02:20.391827
# The maximum UP value of the array is:  0    9
# dtype: int64
# Working time UP is:  0:02:20.605354
# Working time cycle  is:  0:03:47.194350
# Working time pandas is:  0:03:54.736808
# The maximum DOWN value of the array is:  0    9
# dtype: int64
# Working time DOWN is:  0:03:54.942834

# %%
#Speed with Panda
import pandas as pd
import numpy as np
from datetime import datetime
startTime = datetime.now()

data = pd.read_csv("10m.txt", sep="\t", header=None)

max_value = np.max(data)
min_value = np.min(data)
median_value = np.median(data)
average_value = np.average(data)


# Print the maximum value

print('The maximum value of the array is: ', max_value)
print('The minimum value of the array is: ', min_value)
print('The median value of the array is: ', median_value)
print('The average value of the array is: ', average_value)
print('Working time is: ', datetime.now() - startTime)
# Out:
# The maximum value of the array is:  0    49999978
# dtype: int64
# The minimum value of the array is:  0   -49999996
# dtype: int64
# The median value of the array is:  25216.0
# The average value of the array is:  7364.418442641844
# Working time is:  0:00:10.881882
